# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from numpy.random import rand
# %matplotlib notebook

import numpy as np
# Out:
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/hp/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
def NN(config,i,j,L):
#nearest  neighbours   
  
        return [[(i+1)%L,j],[i,(j-1)%L],[(i-1)%L,j],[i,(j+1)%L]]
def nearest(grid,i,j,L):
#spin of nearest neighbours    
    q1=[]
    q=NN(grid,i%L,j%L,L)
    for i in q:
        if i!=0 :
           
            q1.append(grid[i[0],i[1]])
        else:
            q1.append(0)
    return q1

# %%
qr=[14,23,37,92,95]
qrr=[1,2,3,4,5]
plt.plot(qrr,qr)
plt.xlabel('No of spins')
plt.ylabel('J')

plt.legend()
plt.savefig('J')
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
#nearest(grid,1,10,10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-48b65ecc875f> in <module>
# ----> 1 nearest(grid,1,10,10)
#
# NameError: name 'grid' is not defined

# %%
from copy import deepcopy
#labeling and allerstory linaer
def jj(grid,i,j,L,p):
    d=NN(grid,i,j,L)
  
    
    J=[]
    w=[]
    for k in d:
        if k!=0:
            w.append(p[i,j]+p[k[0],k[1]])
        else:
            w.append(0)
            
    for m in w:
        if m== b'FF':
            J.append(100)
        elif m==b'DD':
            J.append(1)
        elif m== b'DF' or m==b'FD':
            J.append(10)
        elif m==b'EF' or m==b'FE':
            
            J.append(15)
        elif m==b'GF' or m==b'FG':
            J.append(35)
        elif m==b'HF' or m==b'FH':
            J.append(55)
        elif m==b'IF' or m==b'FI':
            J.append(75)
        elif m==b'JF' or m==b'FJ':
            J.append(95)
        elif m==b'GG' :
            J.append(35)
        elif m==b'HH':
            J.append(55)
        elif m==b'II' :
            J.append(75)
        elif m==b'JJ':
            J.append(95)
        else:
            J.append(1)
            
  
            
    return J
def jj1(grid,i,j,L,p):
    d=NN(grid,i,j,L)
#labeling and allerstory sigmoidal  
    
    J=[]
    w=[]
    for k in d:
        if k!=0:
            w.append(p[i,j]+p[k[0],k[1]])
        else:
            w.append(0)
            
    for m in w:
        if m== b'FF':
            J.append(100)
        elif m==b'DD':
            J.append(1)
        elif m== b'DF' or m==b'FD':
            J.append(10)
        elif m==b'EF' or m==b'FE':
            
            J.append(14)
        elif m==b'GF' or m==b'FG':
            J.append(25)
        elif m==b'HF' or m==b'FH':
            J.append(37)
        elif m==b'IF' or m==b'FI':
            J.append(92)
        elif m==b'JF' or m==b'FJ':
            J.append(95)
        elif m==b'GG' :
            J.append(25)
        elif m==b'HH':
            J.append(37)
        elif m==b'II' :
            J.append(92)
        elif m==b'JJ':
            J.append(95)
        else:
            J.append(1)
            
    return J
    

def jj12(grid,i,j,L,p):
    d=NN(grid,i,j,L)
  
    
    J=[]
    w=[]
    for k in d:
        if k!=0:
            w.append(p[i,j]+p[k[0],k[1]])
        else:
            w.append(0)
            
    for m in w:
        if m== b'FF':
            J.append(100)
        elif m==b'DD':
            J.append(1)
        elif m== b'DF' or m==b'FD':
            J.append(10)
        elif m==b'EF' or m==b'FE':
            J.append(14)
        elif m==b'GE' or m==b'EG':
            J.append(25)
        elif m==b'HG' or m==b'GH':
            J.append(37)
        elif m==b'IG' or m==b'GI':
            J.append(92)
        elif m==b'JG' or m==b'GJ':
            J.append(95)
        else:
            J.append(1)
            
    return J
def jj13(grid,i,j,L,p):
    d=NN(grid,i,j,L)
  
    
    J=[]
    w=[]
    for k in d:
        if k!=0:
            w.append(p[i,j]+p[k[0],k[1]])
        else:
            w.append(0)
            
    for m in w:
        if m== b'FF':
            J.append(100)
        elif m==b'DD':
            J.append(1)
        elif m== b'DF' or m==b'FD':
            J.append(10)
        elif m==b'EF' or m==b'FE':
            J.append(20)
        elif m==b'GE' or m==b'EG':
            J.append(40)
        elif m==b'HG' or m==b'GH':
            J.append(60)
        elif m==b'IG' or m==b'GI':
            J.append(80)
        elif m==b'JG' or m==b'GJ':
            J.append(100)
        else:
            J.append(0)
            
    return J
              
def jj2(grid,i,j,L,p):
    d=NN(grid,i,j,L)
 #no allestory 
    
    J=[]
    w=[]
    for k in d:
        if k!=0:
            w.append(p[i,j]+p[k[0],k[1]])
        else:
            w.append(0)
            
    for m in w:
        if m== b'FF':
            J.append(100)
        elif m==b'DD':
            J.append(1)
        elif m== b'DF' or m==b'FD':
            J.append(10)
       
        else:
            J.append(1)
            
    return J

# %%
a= np.ones([3,3])
a[1,2]=2
#co-ordiante of interfacial cells in general ()
def rinterfacial(grid,i,j,L): #i j, is center of template and L size of grid 
    q1=interfacial(grid,i,j,L)
    
    q1=[y for y in q1 if y[1]>j]
    
    
    return q1
def interfacial(grid,i,j,L):
    q=NN(grid,i,j,L)
    q1=[]
    for k in q:
        q1+=NN(grid,k[0],k[1],L)
    
    q1= duplicate(q1)
    if [i,j] in q1:
        q1.remove([i,j])
    return q1
def linterfacial(grid,i,j,L):
    a=interfacial(grid,i,j,L)
    c=[y for y in a if y[1]<j]
    return c
def topinterfacial(grid,i,j,L):
    
    return [[i-2,j]]
def botinterfacial(grid,i,j,L):
  
    return [[i+2,j]]

    
def duplicate(a): # list duplicating
    b=[]
    for i in a:
        if i not in b:
            b.append(i)
    return b

# %%
def make(grid): # reducing to same 
    new=grid.copy()
    for i in range(len(grid)):
        for j in range(len(grid)):
            if grid[i][j]==10:
                new[i][j]=1
    return new

# %%
def create_d(grid,listf):
    L =len(grid)
    new_grid =np.chararray((L, L))
    new_grid[:]='D'
    for l in listf:
        de=NN(grid,l[0],l[1],L)+[[l[0],l[1]]]
        de1=rinterfacial(grid,l[0],l[1],L)
        de2=linterfacial(grid,l[0],l[1],L)
        de3=topinterfacial(grid,l[0],l[1],L)
        de4=botinterfacial(grid,l[0],l[1],L)
        new_grid[l[0],l[1]]='F'
        for i in range(L):
            for j in range(L):
                if [i,j] in de:
                    new_grid[i,j]='F'
                if [i,j] in de1 and  grid[i,j]==1:
                    if new_grid[i,j]!=b'F':
                        new_grid[i,j]='E'
                        if grid[i,(j+1)%L]==1 and new_grid[i,(j+1)%L]!=b'F':
                            new_grid[i,(j+1)%L]='G'
                            if grid[(i+1)%L,(j+1)%L]==1 and new_grid[(i+1)%L,(j+1)%L]!=b'F':
                                new_grid[(i+1)%L,(j+1)%L]='H'
                                if grid[(i-1)%L,(j+1)%L]==1 and new_grid[(i-1)%L,(j+1)%L]!=b'F':
                                    new_grid[(i-1)%L,(j+1)%L]='I'
                                    if grid[i,(j+2)%L]==1 and new_grid[i,(j+2)%L]!=b'F':
                                        new_grid[i,(j+2)%L]='J'
                elif [i,j] in de2 and grid[i,j]==1:
                    if new_grid[i,j]!=b'F':
                        new_grid[i,j]='E'
                        if grid[i,(j-1)%L]==1 and new_grid[i,(j-1)%L]!=b'F' :
                            new_grid[i,(j-1)%L]='G'
                            if grid[(i+1)%L,(j-1)%L]==1 and new_grid[(i+1)%L,(j-1)%L]!=b'F':
                                new_grid[(i+1)%L,(j-1)%L]='H'
                                if grid[(i-1)%L,(j-1)%L]==1 and new_grid[(i-1)%L,(j-1)%L]!=b'F':
                                    new_grid[(i-1)%L,(j-1)%L]='I'
                                    if grid[i,(j-2)%L]==1 and new_grid[i,(j-2)%L]!=b'F':
                                        new_grid[i,(j-2)%L]='J'
                elif [i,j] in de3 and grid[i,j]==1:
                    if new_grid[i,j]!=b'F':
                        new_grid[i,j]='E'
                        if grid[(i-1)%L,(j)%L]==1 and [(i-1)%L,(j)%L]!=b'F' :
                            new_grid[(i-1)%L,(j)%L]='G'
                            if grid[(i-1)%L,(j-1)%L]==1 and new_grid[(i-1)%L,(j-1)%L]!=b'F':
                                new_grid[(i-1)%L,(j-1)%L]='H'
                                if grid[(i-1)%L,(j+1)%L]==1 and new_grid[(i-1)%L,(j+1)%L]!=b'F':
                                    new_grid[(i-1)%L,(j+1)%L]='I'
                                    if grid[(i-2)%L,(j)%L]==1 and new_grid[(i-2)%L,(j)%L]!=b'F':
                                        new_grid[(i-2)%L,(j)%L]='J'
                elif [i,j] in de4 and grid[i,j]==1:
                    if new_grid[i,j]!=b'F':
                        new_grid[i,j]='E'
                        if grid[(i+1)%L,(j)%L]==1 and new_grid[(i+1)%L,(j)%L]!=b'F':
                            new_grid[(i+1)%L,(j)%L]='G'
                            if grid[(i+1)%L,(j-1)%L]==1 and new_grid[(i+1)%L,(j-1)%L]!=b'F':
                                new_grid[(i+1)%L,(j-1)%L]='H'
                                if grid[(i+1)%L,(j+1)%L]==1 and new_grid[(i+1)%L,(j+1)%L]!=b'F' :
                                    new_grid[(i+1)%L,(j+1)%L]='I'
                                    if grid[(i+2)%L,(j)%L]==1 and new_grid[(i+2)%L,(j)%L]!=b'F':
                                        new_grid[(i+2)%L,(j)%L]='J'
                    
                    
                        
                        
                    
                    
                
                
        
       
                    
           
              
    return new_grid
def fix(grid,lis,ngrid):
    L=len(grid)
    for i in lis:
        we=interfacial(grid,i[0],i[1],L)
        for k in we:
            if ngrid[k[0],k[1]]+ngrid[k[0],(k[1]+1)%L]+ngrid[(k[0]+1)%L,(k[1]+1)%L]+ngrid[(k[0]-1)%L,(k[1]+1)%L]+ngrid[(k[0]),(k[1]+2)%L]==b'EGHIJ':
                ngrid[k[0],k[1]]='F'
                ngrid[k[0],(k[1]+1)%L]='F'
                ngrid[(k[0]+1)%L,(k[1]+1)%L]='F'
                ngrid[(k[0]-1)%L,(k[1]+1)%L]='F'
                ngrid[(k[0]),(k[1]+2)%L]='F'
                lis.append([k[0],(k[1]+1)%L])
            elif ngrid[k[0],k[1]]+ngrid[k[0],(k[1]-1)%L]+ngrid[(k[0]+1)%L,(k[1]-1)%L]+ngrid[(k[0]-1)%L,(k[1]-1)%L]+ngrid[(k[0]),(k[1]-2)%L]==b'EGHIJ':
                ngrid[k[0],k[1]]='F'
                ngrid[k[0],(k[1]-1)%L]='F'
                ngrid[(k[0]+1)%L,(k[1]-1)%L]='F'
                ngrid[(k[0]-1)%L,(k[1]-1)%L]='F'
                ngrid[(k[0]),(k[1]-2)%L]='F'
                lis.append([k[0],(k[1]-1)%L])
            elif ngrid[k[0],k[1]]+ngrid[(k[0]-1)%L,(k[1])%L]+ngrid[(k[0]-1)%L,(k[1]-1)%L]+ngrid[(k[0]-1)%L,(k[1]+1)%L]+ngrid[(k[0]-2)%L,(k[1])%L]==b'EGHIJ':
                
                ngrid[k[0],k[1]]='F'
                ngrid[(k[0]-1)%L,(k[1])%L]='F'
                ngrid[(k[0]-1)%L,(k[1]-1)%L]='F'
                ngrid[(k[0]-1)%L,(k[1]+1)%L]='F'
                ngrid[(k[0]-2)%L,(k[1])%L]='F'
                lis.append([(k[0]-1)%L,(k[1])%L])
            elif ngrid[k[0],k[1]]+ngrid[(k[0]+1)%L,(k[1])%L]+ngrid[(k[0]+1)%L,(k[1]-1)%L]+ngrid[(k[0]+1)%L,(k[1]+1)%L]+ngrid[(k[0]+2)%L,(k[1])%L]==b'EGHIJ':
                
                ngrid[k[0],k[1]]='F'
                ngrid[(k[0]+1)%L,(k[1])%L]='F'
                ngrid[(k[0]+1)%L,(k[1]-1)%L]='F'
                ngrid[(k[0]+1)%L,(k[1]+1)%L]='F'
                ngrid[(k[0]+2)%L,(k[1])%L]='F'
                lis.append([(k[0]+1)%L,(k[1])%L])
            
            
    return ngrid,lis

# %%
def make(grid):
    new=grid.copy()
    for i in range(len(grid)):
        for j in range(len(grid)):
            if grid[i][j]==10:
                new[i][j]=1
    return new

# %%
def create_dn(grid,listf): # scanning and checking similar to template
    L =len(grid)
    new_grid =np.chararray((L, L))
    new_grid[:]='D'
    for l in listf:
        de=NN(grid,l[0],l[1],L)+[[l[0],l[1]]]
        de1=rinterfacial(grid,l[0],l[1],L)
        de2=linterfacial(grid,l[0],l[1],L)
        de3=topinterfacial(grid,l[0],l[1],L)
        de4=botinterfacial(grid,l[0],l[1],L)
        new_grid[l[0],l[1]]='F'
        for i in range(L):
            for j in range(L):
                if [i,j] in de:
                    new_grid[i,j]='F'
                if [i,j] in de1 and  grid[i,j]==1:
                    if new_grid[i,j]!=b'F':
                        new_grid[i,j]='E'
                        if grid[i,(j+1)%L]==1 and new_grid[i,(j+1)%L]!=b'F':
                            new_grid[i,(j+1)%L]='G'
                            new_grid[i,j]='G'
                            if grid[(i+1)%L,(j+1)%L]==1 and new_grid[(i+1)%L,(j+1)%L]!=b'F':
                                new_grid[(i+1)%L,(j+1)%L]='H'
                                new_grid[i,(j+1)%L]='H'
                                new_grid[i,j]='H'
                                if grid[(i-1)%L,(j+1)%L]==1 and new_grid[(i-1)%L,(j+1)%L]!=b'F':
                                    new_grid[(i-1)%L,(j+1)%L]='I'
                                    new_grid[(i+1)%L,(j+1)%L]='I'
                                    new_grid[i,(j+1)%L]='I'
                                    new_grid[i,j]='I'
                                    if grid[i,(j+2)%L]==1 and new_grid[i,(j+2)%L]!=b'F':
                                        new_grid[i,(j+2)%L]='J'
                                        new_grid[(i-1)%L,(j+1)%L]='J'
                                        new_grid[(i+1)%L,(j+1)%L]='J'
                                        new_grid[i,(j+1)%L]='J'
                                        new_grid[i,j]='J'
                elif [i,j] in de2 and grid[i,j]==1:
                    if new_grid[i,j]!=b'F':
                        new_grid[i,j]='E'
                        if grid[i,(j-1)%L]==1 and new_grid[i,(j-1)%L]!=b'F' :
                            new_grid[i,(j-1)%L]='G'
                            new_grid[i,j]='G'
                            if grid[(i+1)%L,(j-1)%L]==1 and new_grid[(i+1)%L,(j-1)%L]!=b'F':
                                new_grid[(i+1)%L,(j-1)%L]='H'
                                new_grid[i,(j-1)%L]='H'
                                new_grid[i,j]='H'
                                if grid[(i-1)%L,(j-1)%L]==1 and new_grid[(i-1)%L,(j-1)%L]!=b'F':
                                    new_grid[(i-1)%L,(j-1)%L]='I'
                                    new_grid[(i+1)%L,(j-1)%L]='I'
                                    new_grid[i,(j-1)%L]='I'
                                    new_grid[i,j]='I'
                                    if grid[i,(j-2)%L]==1 and new_grid[i,(j-2)%L]!=b'F':
                                        new_grid[i,(j-2)%L]='J'
                                        new_grid[(i-1)%L,(j-1)%L]='J'
                                        new_grid[(i+1)%L,(j-1)%L]='J'
                                        new_grid[i,(j-1)%L]='J'
                                        new_grid[i,j]='J'
                elif [i,j] in de3 and grid[i,j]==1:
                    if new_grid[i,j]!=b'F':
                        new_grid[i,j]='E'
                        if grid[(i-1)%L,(j)%L]==1 and [(i-1)%L,(j)%L]!=b'F' :
                            new_grid[(i-1)%L,(j)%L]='G'
                            new_grid[i,j]='G'
                            if grid[(i-1)%L,(j-1)%L]==1 and new_grid[(i-1)%L,(j-1)%L]!=b'F':
                                new_grid[(i-1)%L,(j-1)%L]='H'
                                new_grid[(i-1)%L,(j)%L]='H'
                                new_grid[i,j]='H'
                                if grid[(i-1)%L,(j+1)%L]==1 and new_grid[(i-1)%L,(j+1)%L]!=b'F':
                                    new_grid[(i-1)%L,(j+1)%L]='I'
                                    new_grid[(i-1)%L,(j-1)%L]='I'
                                    new_grid[(i-1)%L,(j)%L]='I'
                                    new_grid[i,j]='I'
                                    if grid[(i-2)%L,(j)%L]==1 and new_grid[(i-2)%L,(j)%L]!=b'F':
                                        new_grid[(i-2)%L,(j)%L]='J'
                                        new_grid[(i-1)%L,(j+1)%L]='J'
                                        new_grid[(i-1)%L,(j-1)%L]='J'
                                        new_grid[(i-1)%L,(j)%L]='J'
                                        new_grid[i,j]='J'
                elif [i,j] in de4 and grid[i,j]==1:
                    if new_grid[i,j]!=b'F':
                        new_grid[i,j]='E'
                        if grid[(i+1)%L,(j)%L]==1 and new_grid[(i+1)%L,(j)%L]!=b'F':
                            new_grid[(i+1)%L,(j)%L]='G'
                            new_grid[i,j]='G'
                            if grid[(i+1)%L,(j-1)%L]==1 and new_grid[(i+1)%L,(j-1)%L]!=b'F':
                                new_grid[(i+1)%L,(j-1)%L]='H'
                                new_grid[(i+1)%L,(j)%L]='H'
                                new_grid[i,j]='H'
                                if grid[(i+1)%L,(j+1)%L]==1 and new_grid[(i+1)%L,(j+1)%L]!=b'F' :
                                    new_grid[(i+1)%L,(j+1)%L]='I'
                                    new_grid[(i+1)%L,(j-1)%L]='I'
                                    new_grid[(i+1)%L,(j)%L]='I'
                                    new_grid[i,j]='I'
                                    if grid[(i+2)%L,(j)%L]==1 and new_grid[(i+2)%L,(j)%L]!=b'F':
                                        new_grid[(i+2)%L,(j)%L]='J'
                                        new_grid[(i+1)%L,(j+1)%L]='J'
                                        new_grid[(i+1)%L,(j-1)%L]='J'
                                        new_grid[(i+1)%L,(j)%L]='J'
                                        new_grid[i,j]='J'
                    
                    
                        
                        
                    
                    
                
                
        
       
                    
           
              
    return new_grid
def fixn(grid,lis,ngrid): #Fxing if structue is same as template
    L=len(grid)
    for i in lis:
        we=interfacial(grid,i[0],i[1],L)
        for k in we:
            if ngrid[k[0],k[1]]+ngrid[k[0],(k[1]+1)%L]+ngrid[(k[0]+1)%L,(k[1]+1)%L]+ngrid[(k[0]-1)%L,(k[1]+1)%L]+ngrid[(k[0]),(k[1]+2)%L]==b'JJJJJ':
                ngrid[k[0],k[1]]='F'
                ngrid[k[0],(k[1]+1)%L]='F'
                ngrid[(k[0]+1)%L,(k[1]+1)%L]='F'
                ngrid[(k[0]-1)%L,(k[1]+1)%L]='F'
                ngrid[(k[0]),(k[1]+2)%L]='F'
                lis.append([k[0],(k[1]+1)%L])
            elif ngrid[k[0],k[1]]+ngrid[k[0],(k[1]-1)%L]+ngrid[(k[0]+1)%L,(k[1]-1)%L]+ngrid[(k[0]-1)%L,(k[1]-1)%L]+ngrid[(k[0]),(k[1]-2)%L]==b'JJJJJ':
                ngrid[k[0],k[1]]='F'
                ngrid[k[0],(k[1]-1)%L]='F'
                ngrid[(k[0]+1)%L,(k[1]-1)%L]='F'
                ngrid[(k[0]-1)%L,(k[1]-1)%L]='F'
                ngrid[(k[0]),(k[1]-2)%L]='F'
                lis.append([k[0],(k[1]-1)%L])
            elif ngrid[k[0],k[1]]+ngrid[(k[0]-1)%L,(k[1])%L]+ngrid[(k[0]-1)%L,(k[1]-1)%L]+ngrid[(k[0]-1)%L,(k[1]+1)%L]+ngrid[(k[0]-2)%L,(k[1])%L]==b'JJJJJ':
                
                ngrid[k[0],k[1]]='F'
                ngrid[(k[0]-1)%L,(k[1])%L]='F'
                ngrid[(k[0]-1)%L,(k[1]-1)%L]='F'
                ngrid[(k[0]-1)%L,(k[1]+1)%L]='F'
                ngrid[(k[0]-2)%L,(k[1])%L]='F'
                lis.append([(k[0]-1)%L,(k[1])%L])
            elif ngrid[k[0],k[1]]+ngrid[(k[0]+1)%L,(k[1])%L]+ngrid[(k[0]+1)%L,(k[1]-1)%L]+ngrid[(k[0]+1)%L,(k[1]+1)%L]+ngrid[(k[0]+2)%L,(k[1])%L]==b'JJJJJ':
                
                ngrid[k[0],k[1]]='F'
                ngrid[(k[0]+1)%L,(k[1])%L]='F'
                ngrid[(k[0]+1)%L,(k[1]-1)%L]='F'
                ngrid[(k[0]+1)%L,(k[1]+1)%L]='F'
                ngrid[(k[0]+2)%L,(k[1])%L]='F'
                lis.append([(k[0]+1)%L,(k[1])%L])
            
            
    return ngrid,lis

# %%
#saving the simulated data grids
def init2(L):
    for i in range(L):
        for j in range(L):
            if i==L//2 :
                if j==L//2 -1 or j==L//2 +1:
                    grid[i,j]=10
                elif  j==L//2 :
                    grid[i,j]=10
                else:
                     grid[i,j]=int(np.random.choice([-1,1],size=1))
                    
            elif i==L//2 -1:
                if j==L//2:
                    grid[i,j]=10
                else:
                     grid[i,j]=int(np.random.choice([-1,1],size=1))
                        
            elif i==L//2 +1:
                if j==L//2:
                    grid[i,j]=10
                else:
                     grid[i,j]=2*np.random.randint(0,1)-1
            else:
                grid[i,j]=int(np.random.choice([-1,1],size=1))
    return grid

stored_grid=[]
m=[[],[],[],[],[],[]]
for L in range(50,100,10):
    grid=np.zeros([L,L])
    grid=init2(L)
    grid=make(grid)
    
    x =[]
    y =[]
    u=(L//10)-5
    lis =[[L//2,L//2]]
    new_grid = grid.copy()
    
    d45=create_dn(new_grid,lis)
 
    for o in range(0,120): #steps
        
        
        nlis =lis[:]
        L = len(grid)
    
        for i in range(L**2):
            a = np.random.randint(0, L) 
            b = np.random.randint(0, L)
            sigm =  grid[a, b]
            
            del_E = 2*np.sum(np.array(jj2(new_grid,a,b,L,d45))*np.array(nearest(new_grid,a,b,L))*new_grid[a,b])

            if del_E < 0:
                sigm *= -1
            elif rand() < np.exp(-del_E*.23):
                sigm *= -1
            new_grid[a, b] = sigm
        ne=new_grid[:]
        d46 =create_dn(new_grid,nlis)

        d45,lis=fixn(new_grid,nlis,d46)
        
        
        print(len(lis))
        
        m[u].append(len(duplicate(lis)))
        
        x.append(o)
        
 
    
    
   
  
        grid=new_grid
       
    
 
    
    
    
    
  
                    
            
  
    
    
    
np.savetxt('data12.txt', m)
# Out:
# 1
# 1
# 1
# 1
# 1
# 2
# 3
# 4
# 5
# 8
# 10
# 14
# 19
# 24
# 26
# 28
# 29
# 31
# 33
# 36
# 41
# 44
# 46
# 49
# 55
# 59
# 65
# 72
# 78
# 84
# 93
# 101
# 114
# 125
# 134
# 145
# 161
# 174
# 181
# 191
# 199
# 215
# 220
# 230
# 240
# 252
# 260
# 262
# 273
# 279
# 286
# 291
# 297
# 298
# 299
# 303
# 307
# 311
# 314
# 317
# 320
# 322
# 322
# 327
# 328
# 330
# 332
# 334
# 334
# 334
# 335
# 335
# 335
# 335
# 336
# 336
# 337
# 338
# 338
# 338
# 338
# 338
# 338
# 338
# 338
# 338
# 338
# 338
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 339
# 1
# 2
# 4
# 6
# 7
# 8
# 9
# 11
# 14
# 16
# 19
# 21
# 22
# 22
# 24
# 27
# 32
# 34
# 37
# 39
# 47
# 55
# 60
# 67
# 75
# 84
# 89
# 100
# 109
# 121
# 129
# 134
# 138
# 146
# 155
# 167
# 176
# 184
# 195
# 208
# 222
# 232
# 243
# 259
# 272
# 285
# 297
# 316
# 329
# 335
# 343
# 349
# 362
# 368
# 377
# 385
# 394
# 407
# 419
# ...

# %%
plt.plot(m[0])
plt.plot(mn[0])
# Out:
# <div id='398c160a-ebb2-4cec-b053-206a3b841d02'></div>

# %%
from copy import deepcopy
import matplotlib.gridspec as gridspec

fig = plt.figure(num=2,figsize=(8,4))
gs = gridspec.GridSpec(1, 2, width_ratios=[1,1])
ax0 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1])
L=50
grid1=np.zeros([L,
              L])
def init2(L):
    for i in range(L):
        for j in range(L):
            if i==L//2 :
                if j==L//2 -1 or j==L//2 +1:
                    grid1[i,j]=10
                elif  j==L//2 :
                    grid1[i,j]=10
                else:
                     grid1[i,j]=int(np.random.choice([-1,1],size=1))
                    
            elif i==L//2 -1:
                if j==L//2:
                    grid1[i,j]=10
                else:
                     grid1[i,j]=int(np.random.choice([-1,1],size=1))
                        
            elif i==L//2 +1:
                if j==L//2:
                    grid1[i,j]=10
                else:
                     grid1[i,j]=2*np.random.randint(0,1)-1
            else:
                grid1[i,j]=int(np.random.choice([-1,1],size=1))
    return grid1


grid1=init2(L)

mat = ax0.matshow(grid1,cmap= 'RdBu')
line, = ax1.plot(0, 0, lw=2)

lis1 =[[L//2,L//2]]
grid1=make(grid1)
line, = ax1.plot(0, 0, lw=2)
x = []
y = []
m= []
def update(o):
    
    
    global grid1,lis1,m
    
    new_grid1 = grid1[:]
    
    d44 =create_dn(new_grid1,lis1)
    for i in range(100):
        mc(grid1,d44)
    nlis =lis1[:]
    L = len(grid1)
    
    
    for i in range(L**2):
        
           
            a = np.random.randint(0, L) 
            b = np.random.randint(0, L)
            sigm =  grid1[a, b]
            
            del_E = 2*np.sum(np.array(jj12(new_grid1,a,b,L,d44))*np.array(nearest(new_grid1,a,b,L))*new_grid1[a,b])
            if del_E < 0:
                sigm *= -1
            elif rand() < np.exp(-del_E*.310):
                sigm *= -1
            new_grid1[a, b] = sigm
    
               
    ne1=deepcopy(new_grid1)
    
    d415 =create_dn(new_grid1,lis1)

    d44,lis1 =fixn(new_grid1,nlis,d415)
    m.append(len(lis1))
    
    for i in range(L):
        for j in range(L):
            if d44[i][j] ==b'F':
                ne1[i][j] =10
    
                
            
    mat.set_data(ne1) 
    x.append(o)
    y.append(m[o])
 
    
    
    ax1.clear()
    ax1.plot(x, y)
    
  
                    
            
  
    grid1=new_grid1
    
  
    return [mat]
anim1 = animation.FuncAnimation(fig, update,interval=100,frames=100,blit=True)
#simulated replication againts & number (aggreagated) copies formed
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
len(grid1)
# Out:
# 50

# %%
m[3]
# Out:
# []

# %%
plt.plot(m2[0],label='L= 50')
plt.plot(m2[1],label='L= 60')
plt.plot(m2[2],label='L= 70')
plt.plot(m2[3],label= 'L= 80')
plt.yscale('log')
plt.xlabel('montecarlo steps')
plt.ylabel('n_s')
plt.legend()
plt.savefig('growthlnp11')
#growth curves for various dimesion of lattice
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(m[0],label='linear')
plt.plot(m1[0],label='sigmoid')
plt.plot(m2[0],label='no allostery')
plt.legend()
plt.xlabel('montecarlo steps')
plt.ylabel('n_s')

plt.savefig('rep331.jpg')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(x11[1:qw],rty[1:qw],label='L=50')
plt.plot(x112[1:qw1],m1[1][1:qw1],label='L=60')
plt.plot(x113[1:qw2],m1[2][1:qw2],label='L=70')
plt.yscale('log')
plt.savefig('lino')
plt.legend()
plt.xlabel('montecarlo steps')
plt.ylabel('n_s')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(39.426826714409714, 0.5, 'n_s')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import pchip


mylist = m1[0]
mylist_np = np.array(mylist)
samples = np.array(range(len(mylist)))    
xnew = np.linspace(samples.min(), samples.max(), 100)
plt.plot(xnew,pchip(samples, mylist_np )(xnew))
mylist1 = m1[1]
mylist_np1 = np.array(mylist1)
samples1 = np.array(range(len(mylist1)))    
xnew1 = np.linspace(samples1.min(), samples1.max(), 100)
plt.plot(xnew,pchip(samples1, mylist_np1 )(xnew1))
mylist2 = m1[2]
mylist_np2 = np.array(mylist2)
samples2 = np.array(range(len(mylist2)))    
xnew2 = np.linspace(samples2.min(), samples2.max(), 100)
plt.plot(xnew2,pchip(samples2, mylist_np2 )(xnew2))
plt.yscale('log')
plt.xlim(0,50)
plt.savefig('fitedlogl11')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import pchip


mylist = m2[0]
mylist_np = np.array(mylist)
samples = np.array(range(len(mylist)))    
xnew = np.linspace(samples.min(), samples.max(), 1000)
plt.plot(xnew,pchip(samples, mylist_np )(xnew))
mylist1 = m2[1]
mylist_np1 = np.array(mylist1)
samples1 = np.array(range(len(mylist1)))    
xnew1 = np.linspace(samples1.min(), samples1.max(), 1000)
plt.plot(xnew,pchip(samples1, mylist_np1 )(xnew1))
mylist2 = m2[2]
mylist_np2 = np.array(mylist2)
samples2 = np.array(range(len(mylist2)))    
xnew2 = np.linspace(samples2.min(), samples2.max(), 1000)
plt.plot(xnew2,pchip(samples2, mylist_np2 )(xnew2))
plt.yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rty1=[]
x112=[]
for u in range(len(m[1])):
    if u%5==0:
        x112.append(u)
        rty1.append(m[1][u])
plt.plot(x112[1:],np.diff(rty1)/5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rty=[]
x11=[]
for u in range(len(m1[0])):
    if u%2==0:
        x11.append(u)
        rty.append(m1[0][u])

rty1=[]
x111=[]
for u in range(len(m1[1])):
    if u%1==0:
        x111.append(u)
        rty1.append(m1[1][u])

rty3=[]
x113=[]
for u in range(len(m1[3])):
    if u%1==0:
        x113.append(u)
        rty3.append(m1[3][u])


rty2=[]
x112=[]
for u in range(len(m1[2])):
    if u%2==0:
        x112.append(u)
        rty2.append(m1[2][u])

rty4=[]
x114=[]
for u in range(len(m[4])):
    if u%1==0:
        x114.append(u)
        rty4.append(m[4][u])



rtmax=[]
qq=(np.diff(rty))
qq1=(np.diff(rty1))
qq2=(np.diff(rty2))
qq3=(np.diff(rty3))
plt.plot(x11,qq,label='L=50')
plt.plot(x111,qq1,label='L=60')
plt.plot(x112,qq2,label='L=70')
plt.plot(x113,qq3,label='L=80')

plt.legend(loc='best')
plt.ylabel('dN/ds')
plt.xlabel('Steps')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-e0d30a77026d> in <module>
#      30 rty4=[]
#      31 x114=[]
# ---> 32 for u in range(len(m[4])):
#      33     if u%1==0:
#      34         x114.append(u)
#
# TypeError: object of type 'int' has no len()

# %%
len(np.diff(rty))
# Out:
# 119

# %%
qq=list(np.gradient(rty))
qq1=list(np.gradient(rty1))
qq2=list(np.gradient(rty2))
qq3=list(np.diff(rty3))
qw=qq.index(max(qq))
qw1=qq1.index(max(qq1))

qw2=qq2.index(max(qq2))
qw3=qq3.index(max(qq3))
y=[qw,qw1,qw2,qw4]
yy=[50,60,70,80]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-60603bd1bdf4> in <module>
#       8 qw2=qq2.index(max(qq2))
#       9 qw3=qq3.index(max(qq3))
# ---> 10 y=[qw,qw1,qw2,qw4]
#      11 yy=[50,60,70,80]
#      12
#
# NameError: name 'qw4' is not defined

# %%
qw1
# Out:
# 22

# %%
plt.plot(x11[10:qw],(rty)[10:qw],'.-',label= 'L 50')
plt.plot(x111[20:qw1],(rty1)[20:qw1],'.-',label= 'L 60')
plt.plot(x112[10:qw2],(rty2)[10:qw2],'.-',label= 'L 70')
plt.yscale('log')
plt.legend()
plt.xlabel('montecarlo steps')
plt.ylabel('n_s')
plt.savefig('li')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(m[0])
plt.plot(m[1])
plt.plot(m[2])
plt.yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rty1=[]
x112=[]
for u in range(len(m[4])):
    if u%5==0:
        x112.append(u)
        rty1.append(m[4][u])
plt.plot(x112[1:],np.diff(rty1)/5)
